# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# La casa más cara del dataset
inmueble_precio_mayor = ds['price'].idxmax()

# Dirección y precio de la casa más cara
direccion_inmueble_mayor_precio = ds.loc[inmueble_precio_mayor,'address']
precio_inmueble_mayor_precio = ds.loc[inmueble_precio_mayor,'price']

print(f' La dirección de la casa más cara del dataset es {direccion_inmueble_mayor_precio} que tiene un precio de {precio_inmueble_mayor_precio} USD')
# Out:
#  La dirección de la casa más cara del dataset es El Escorial que tiene un precio de 8500000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# La casa más barata del dataset
inmueble_precio_menor = ds['price'].idxmin()

# Dirección y precio de la casa más barata
direccion_inmueble_menor_precio = ds.loc[inmueble_precio_menor,'address']
precio_inmueble_menor_precio = ds.loc[inmueble_precio_menor,'price']

print(f' La dirección de la casa más barata del dataset es {direccion_inmueble_menor_precio} que tiene un precio de {precio_inmueble_menor_precio} USD')
# Out:
#  La dirección de la casa más barata del dataset es Parla que tiene un precio de 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
#Datos casa más grande
casa_mayor_tamanyo = ds['surface'].idxmax()
direccion_inmueble_mayor_tamanyo = ds.loc[casa_mayor_tamanyo,'address']
precio_inmueble_mayor_tamanyo = ds.loc[casa_mayor_tamanyo,'price']

#Datos casa más pequeña
casa_menor_tamanyo = ds['surface'].idxmin()
direccion_inmueble_menor_tamanyo = ds.loc[casa_menor_tamanyo,'address']
precio_inmueble_menor_tamanyo = ds.loc[casa_menor_tamanyo,'price']

print(f' La dirección de la casa con mayor superficie es {direccion_inmueble_mayor_tamanyo} que tiene un precio de {precio_inmueble_mayor_tamanyo} USD')
print(f' La dirección de la casa con menor superficie es {direccion_inmueble_menor_tamanyo} que tiene un precio de {precio_inmueble_menor_tamanyo} USD')
# Out:
#  La dirección de la casa con mayor superficie es Sevilla la Nueva que tiene un precio de 289000 USD
#  La dirección de la casa con menor superficie es Calle Amparo,  Madrid Capital que tiene un precio de 85000 USD

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
import pandas as pd

ds = pd.read_csv('assets/real_estate.csv', sep=';')
poblaciones_nombre = ', '.join(ds["level5"])
print(poblaciones_nombre)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Fuenlabrada, Arganda del Rey, Las Rozas de Madrid, Las Rozas de Madrid, Las Rozas de Madrid, Las Rozas de Madrid,  Madrid Capital,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero,  Madrid Capital,  Madrid Capital,  Madrid Capital, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes,  Madrid Capital, Rivas-vaciamadrid, Alpedrete,  Madrid Capital,  Madrid Capital,  Madrid Capital, Móstoles,  Madrid Capital,  Madrid Capital,  Madrid Capital, San Fernando de Henares, Coslada,  Madrid Capital, Becerril de la Sierra,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Alcalá de Henares,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Pinto,  Madrid Capital,  Madrid Capita
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
import pandas as pd

#uso de índice booleano para identificar dónde se ecuentran los datos NAs
bool_index = ds == 'NaN'
print(bool_index)
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
ds_sin_nas = ds.dropna()

dimesion_ds_original = ds.shape
dimension_ds_sin_nas = ds_sin_nas.shape
print('Dimension DataFrame original: ', dimesion_ds_original)
print('Dimension DataFrame sin NAs: ', dimension_ds_sin_nas)
# Out:
# Dimension DataFrame original:  (15335, 37)
# Dimension DataFrame sin NAs:  (0, 37)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
#Seleccionar resultados sólo para la población de Arroyomolinos
resultados_poblacion_arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

#Calcular el precio medio para los inmuebles de Arroyomolinos
media_precio_poblacion_arroyomolinos = round(resultados_poblacion_arroyomolinos['price'].mean(),2)
print(f' La media de precios en la población Arroyomolinos(Madrid) es de {media_precio_poblacion_arroyomolinos} USD')
# Out:
#  La media de precios en la población Arroyomolinos(Madrid) es de 294541.6 USD

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %% [markdown]
# Existe en el mercado inmobiliario de Arroyomolinos una prevalencia en el precio de la vivienda entre los 250,000 y 350,000 USD.
# En esta zona los precios de la vivienda por debajo de los 100,000 USD y por encima de los 450,000 USD no se dan con frecuencia.

# %%
# TODO: Code
import matplotlib.pyplot as plt

numero_viviendas_arroyomolinos = resultados_poblacion_arroyomolinos.shape
print(numero_viviendas_arroyomolinos)

plt.hist(resultados_poblacion_arroyomolinos['price'], bins=5)
plt.xlabel ('Rango de precios de inmuebles (USD)')
plt.ylabel ('Frecuencia para cada rango de precios')
plt.title('Histograma de precios Arroyomolinos')

plt.show
# Out:
# (137, 37)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %% [markdown]
# Los precios de ambas poblaciones son similares. Sin embargo, el precio medio de Valdemorillo supera en aproximadamente 4,000 USD el de Galapagar.

# %%
#Seleccionar resultados sólo para la población de Valdemorillo
resultados_poblacion_valdemorillo = ds[ds['level5'] == 'Valdemorillo']

#Calcular el precio medio para los inmuebles de Valdemorillo
media_precio_poblacion_valdemorillo = round(resultados_poblacion_valdemorillo['price'].mean(),2)
print(f' La media de precios en la población Valdemorillo es de {media_precio_poblacion_valdemorillo} USD')

#Seleccionar resultados sólo para la población de Galapagar
resultados_poblacion_galapagar = ds[ds['level5'] == 'Galapagar']

#Calcular el precio medio para los inmuebles de Galapagar
media_precio_poblacion_galapagar = round(resultados_poblacion_galapagar['price'].mean(),2)
print(f' La media de precios en la población Galapagar es de {media_precio_poblacion_galapagar} USD')
# Out:
#  La media de precios en la población Valdemorillo es de 363860.29 USD
#  La media de precios en la población Galapagar es de 360063.2 USD

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# crear nueva columna pps
ds['pps'] = ds['price'] / ds['surface']

#seleccional los precios por metro cuadrado para Valdemorillo
resultados_valdemorillo = ds[ds['level5'] == 'Valdemorillo']
precio_metrocuadrado_valdemorillo = round(resultados_valdemorillo['pps'].mean(),2)
print (f' El precio medio por metro cuadrado en Valdemorillo es de {precio_metrocuadrado_valdemorillo}')

#seleccional los precios por metro cuadrado para Galapagar
resultados_Galapagar = ds[ds['level5'] == 'Galapagar']
precio_metrocuadrado_Galapagar = round(resultados_Galapagar['pps'].mean(),2)
print (f' El precio medio por metro cuadrado en Galapagar es de {precio_metrocuadrado_Galapagar}')
# Out:
#  El precio medio por metro cuadrado en Valdemorillo es de 1317.95
#  El precio medio por metro cuadrado en Galapagar es de 1606.32

# %% [markdown]
# El precio por metro cuadrado en Galapagar es superior al precio medio de Valdemorillo.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.scatter(ds['price'], ds['surface'])
plt.title('Relación entre superficie y precio de inmuebles')
plt.xlabel('Precio')
plt.ylabel('Superficie')
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# Selección de agencias de inmueble
numero_agencias = ds['realEstate_name'].nunique()
print(f' El número de agecias de bienes raíces que contiene el dataset es de {numero_agencias}')
# Out:
#  El número de agecias de bienes raíces que contiene el dataset es de 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# Crear agrupación por level5
conteo_inmuebles_por_poblacion = ds['level5'].value_counts()

# Localizar la población con más casos
población_mayor_concentracion_inmuebles = conteo_inmuebles_por_poblacion.idxmax()
numero_inmuebles_mayor_concentracion = conteo_inmuebles_por_poblacion.max()

print(f' La población con mayor número de inmuebles es {población_mayor_concentracion_inmuebles}, que registra un total de {numero_inmuebles_mayor_concentracion}')
# Out:
#  La población con mayor número de inmuebles es  Madrid Capital, que registra un total de 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# crear el subconjunto
poblaciones_cinturon_sur_madrid = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']
ds_subconjunto_cinturon_sur = ds[ds['level5'].isin(poblaciones_cinturon_sur_madrid)]

print(ds_subconjunto_cinturon_sur)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# cálculo de la mediana de precios
mediana_por_poblacion = ds_subconjunto_cinturon_sur.groupby('level5')['price'].median()
print(mediana_por_poblacion)

# crear gráfico de barras
mediana_por_poblacion.plot(kind='bar',color='orange')

plt.title('Comparación entre poblaciones de precios')
plt.xlabel('Población')
plt.ylabel('Mediana precio')

plt.show()
# Out:
# level5
# Alcorcón       179500.0
# Fuenlabrada    155000.0
# Getafe         285305.0
# Leganés        169950.0
# Name: price, dtype: float64

# %% [markdown]
# En el Cinturón Sur la población que registra un mayor precio de los inmuebles es Getafe con una mediana de casi 290,000 USD.  Lo siguen aunque a otra escala las siguientes poblaciones: Alcorcón, Leganés y Fuenlabrada, que registran correspondientemente 179,500 USD, 169,950 USD y 155,000 USD.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# Calcular la media
media_precio = ds_subconjunto_cinturon_sur.groupby('level5')['price'].mean()
print (round(media_precio))

media_habitaciones = ds_subconjunto_cinturon_sur.groupby('level5')['rooms'].mean()
print (round(media_habitaciones),2)

media_superficie = ds_subconjunto_cinturon_sur.groupby('level5')['surface'].mean()
print (round(media_superficie),2)

media_banyos = ds_subconjunto_cinturon_sur.groupby('level5')['bathrooms'].mean()
print (round(media_banyos),2)

# Calcular varianza
varianza_precio =  ds_subconjunto_cinturon_sur.groupby('level5')['price'].var()
print (varianza_precio)

varianza_habitaciones = ds_subconjunto_cinturon_sur.groupby('level5')['rooms'].var()
print (round(varianza_habitaciones),2)

varianza_superficie = ds_subconjunto_cinturon_sur.groupby('level5')['surface'].var()
print (round(varianza_superficie),2)

varianza_banyos = ds_subconjunto_cinturon_sur.groupby('level5')['bathrooms'].var()
print (round(varianza_banyos),2)
# Out:
# level5
# Alcorcón       230071.0
# Fuenlabrada    177198.0
# Getafe         265040.0
# Leganés        208682.0
# Name: price, dtype: float64
# level5
# Alcorcón       3.0
# Fuenlabrada    3.0
# Getafe         3.0
# Leganés        3.0
# Name: rooms, dtype: float64 2
# level5
# Alcorcón       106.0
# Fuenlabrada    104.0
# Getafe         127.0
# Leganés        106.0
# Name: surface, dtype: float64 2
# level5
# Alcorcón       2.0
# Fuenlabrada    1.0
# Getafe         2.0
# Leganés        2.0
# Name: bathrooms, dtype: float64 2
# level5
# Alcorcón       1.594783e+10
# Fuenlabrada    4.701021e+09
# Getafe         2.098267e+10
# Leganés        1.191394e+10
# Name: price, dtype: float64
# level5
# Alcorcón       1.0
# Fuenlabrada    0.0
# Getafe         1.0
# Leganés        1.0
# Name: rooms, dtype: float64 2
# level5
# Alcorcón       4244.0
# Fuenlabrada    2265.0
# Getafe         5828.0
# Leganés        3987.0
# Name: surface, dtype: float64 2
# level5
# Alcorcón       1.0
# ...

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# Las casa más cara por población
datos_alcorcon = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == 'Alcorcón']
datos_fuenlabrada = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == 'Fuenlabrada']
datos_getafe = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == 'Getafe']
datos_leganes = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == 'Leganés']


# Indicar la casa de mayor precio
mayor_precio_alcorcon = datos_alcorcon['price'].idxmax()
mayor_precio_fuenlabrada = datos_fuenlabrada['price'].idxmax()
mayor_precio_getafe = datos_getafe['price'].idxmax()
mayor_precio_leganes = datos_leganes['price'].idxmax()


# Dirección y precio de la casa más cara
direccion_alcorcon = datos_alcorcon.loc[mayor_precio_alcorcon, 'address']
precio_alcorcon = datos_alcorcon.loc[mayor_precio_alcorcon, 'price']
print(f' La dirección de la casa más cara de Alcorcón es {direccion_alcorcon} que tiene un precio de {precio_alcorcon} USD')

direccion_fuenlabrada = datos_fuenlabrada.loc[mayor_precio_fuenlabrada, 'address']
precio_fuenlabrada = datos_fuenlabrada.loc[mayor_precio_fuenlabrada, 'price']
print(f' La dirección de la casa más cara de Fuenlabrada es {direccion_fuenlabrada} que tiene un precio de {precio_fuenlabrada} USD')

direccion_getafe = datos_getafe.loc[mayor_precio_getafe, 'address']
precio_getafe = datos_getafe.loc[mayor_precio_getafe, 'price']
print(f' La dirección de la casa más cara de Getafe es {direccion_getafe} que tiene un precio de {precio_getafe} USD')


direccion_leganes = datos_leganes.loc[mayor_precio_leganes, 'address']
precio_leganes = datos_leganes.loc[mayor_precio_leganes, 'price']
print(f' La dirección de la casa más cara de Leganés es {direccion_leganes} que tiene un precio de {precio_leganes} USD')
# Out:
#  La dirección de la casa más cara de Alcorcón es Alcorcón que tiene un precio de 950000 USD
#  La dirección de la casa más cara de Fuenlabrada es Calle de Paulo Freire, 5, Fuenlabrada que tiene un precio de 490000 USD
#  La dirección de la casa más cara de Getafe es Getafe que tiene un precio de 1050000 USD
#  La dirección de la casa más cara de Leganés es Avenida Reina Sofía, Leganés que tiene un precio de 650000 USD

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# Normalizar la variable precio
ds_subconjunto_cinturon_sur['precio_normalizado'] = ds_subconjunto_cinturon_sur.groupby('level5')['price'].transform(lambda x: (x - x.min())/(x.max() - x.min()))

# Crear un gráfico de histogramas para las 4 poblaciones
plt.figure(figsize=(10,6))

for poblacion in ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']:
    subset = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == poblacion]
    plt.hist(subset['precio_normalizado'],alpha=0.5, label=poblacion)

plt.title ('Histograma de precios normalizados por población')
plt.xlabel('Precio normalizado')
plt.ylabel('Frecuencia')
plt.legend (title='Poblaciones')

plt.show()
# Out:
# /tmp/ipykernel_459/3778400566.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_subconjunto_cinturon_sur['precio_normalizado'] = ds_subconjunto_cinturon_sur.groupby('level5')['price'].transform(lambda x: (x - x.min())/(x.max() - x.min()))

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# crear nueva columna pps
#ds['pps'] = ds['price'] / ds['surface']

#seleccionar los precios por metro cuadrado para Getafe
resultados_getafe = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == 'Getafe']
precio_metrocuadrado_getafe = round(resultados_valdemorillo['pps'].mean(),2)
print (f' El precio medio por metro cuadrado en Getafe es de {precio_metrocuadrado_getafe}')

#seleccional los precios por metro cuadrado para Alcorcón
resultados_alcorcon = ds_subconjunto_cinturon_sur[ds_subconjunto_cinturon_sur['level5'] == 'Alcorcón']
precio_metrocuadrado_alcorcon = round(resultados_alcorcon['pps'].mean(),2)
print (f' El precio medio por metro cuadrado en Alcorcón es de {precio_metrocuadrado_alcorcon}')
# Out:
#  El precio medio por metro cuadrado en Getafe es de 1317.95
#  El precio medio por metro cuadrado en Alcorcón es de 2239.3

# %% [markdown]
# El precio medio por metro cuadrado el Alcorcón es muy superior al encontrado en Getafe

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
import pandas as pd

# Indicar a Matplotlib que ueremos crear una figura de 2x2
fig, ax= plt.subplots(2,2, figsize =(30,10))

# Subplot 1 Gráfico de dispersión precio vs rooms para Fuenlabrada
ax[0,0].scatter(datos_fuenlabrada['price'], datos_fuenlabrada ['rooms'])
ax[0,0].set_title('Precio vs número de habitaciones en Fuenlabrada')
ax[0,0].set_xlabel('Precio inmueble')
ax[0,0].set_ylabel('Número de habitaciones')

# Subplot 2 Gráfico de dispersión precio vs rooms para Leganés
ax[1,0].scatter(datos_leganes['price'], datos_leganes ['rooms'])
ax[1,0].set_title('Precio vs número de habitaciones en Leganés')
ax[1,0].set_xlabel('Precio inmueble')
ax[1,0].set_ylabel('Número de habitaciones')

# Subplot 3 Gráfico de dispersión precio vs rooms para Getafe
ax[0,1].scatter(datos_getafe['price'], datos_getafe['rooms'])
ax[0,1].set_title('Precio vs número de habitaciones en Getafe')
ax[0,1].set_xlabel('Precio inmueble')
ax[0,1].set_ylabel('Número de habitaciones')

# Subplot 4 Gráfico de dispersión precio vs rooms para Alcorcón
ax[1,1].scatter(datos_alcorcon['price'], datos_alcorcon['rooms'])
ax[1,1].set_title('Precio vs número de habitaciones en Alcorcón')
ax[1,1].set_xlabel('Precio inmueble')
ax[1,1].set_ylabel('Número de habitaciones')

print(datos_fuenlabrada.shape)
print(datos_leganes.shape)
print(datos_getafe.shape)
print(datos_alcorcon.shape)
# Out:
# (233, 38)
# (194, 38)
# (290, 38)
# (190, 38)

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps, Marker

# Mapa centrado en Madrid
map = Map(center = (40.35, -3.8), zoom = 11.5, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.35, -3.8], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_ou…

# %%
## Aquí: traza la coordenadas de los estados
coordenadas_sur = ds_subconjunto_cinturon_sur.set_index('id_realEstates')[['latitude','longitude']].apply(tuple, axis=1)
print(type(coordenadas_sur))

for id_realEstates, (lat, lon) in coordenadas_sur.items():
    marker = Marker(location=(lat, lon), title=str(id_realEstates))
    map.add_layer(marker)
map
# Out:
# <class 'pandas.core.series.Series'>
# Map(bottom=395450.0, center=[40.45060475430765, -3.6958694458007817], controls=(ZoomControl(options=['position…
